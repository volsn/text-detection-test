# %%
import numpy as np

import os
import sys
import time

import matplotlib.pyplot as plt
# %matplotlib inline

from imutils.object_detection import non_max_suppression

import cv2
import pytesseract

# %%
def plt_imshow(image, title=None):
    if title:
        plt.title(title) # Set a title to the plot if one was given
    
    plt.imshow(
        cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    )

# %%
image = cv2.imread('images/private_passport.jpg')
orig = image.copy()
(H, W) = image.shape[:2]

roi = image[H//2:, :]
(H, W) = roi.shape[:2]

# %% [markdown]
# ## Pyimagesearche's Sliding Window

# %%
from pyimagesearch.detection_helpers import sliding_window

# %%
rois = []
for (x, y, roiOrig) in sliding_window(roi, 150, (300, 50)):
    rois.append(roiOrig)

# %%
plt_imshow(rois[40])
